# %%
import re

# %%
result_search = re.search('pattern',r'string to contain pattern')
result_search
# Out:
# <re.Match object; span=(18, 25), match='pattern'>

# %%
result_search2 = re.search('pattern',r'not exicting word')

# %%
print(result_search2)
# Out:
# None

# %%
sen = r'sara is good'

# %%
new_sen = re.sub('sara','sarah',sen)

# %%
new_sen
# Out:
# 'sarah is good'

# %%
customer_review = ["sam was a great help to me in the store",
                   "the cashier was very rude to me, I think her name was eleanor",
                   "amazing work from sadeen!",
                   "sarah was able to help me find the items I needed quickly",
                   "lucy is such a great addition to the team",
                   "great service from sara she found me what i wanted"]

# %%
reviews = []

# %%
pattern_to_find = 'sarah'

# %%
for string in customer_review:
    if(re.search(pattern_to_find , string)):
        reviews.append(string)

# %%
reviews
# Out:
# ['sarah was able to help me find the items I needed quickly']

# %%
reviews2 = []

# %%
pattern_to_find = r'z'

# %%
for char in customer_review:
    if(re.search(pattern_to_find, char)):
        reviews2.append(char)

# %%
reviews2
# Out:
# ['amazing work from sadeen!']

# %%
needwant_reviews = []
pattern_to_find = r"(need| want)ed"

for string in customer_review:
    if (re.search(pattern_to_find, string)):
        needwant_reviews.append(string)

# %%
needwant_reviews
# Out:
# ['sarah was able to help me find the items I needed quickly',
#  'great service from sara she found me what i wanted']
